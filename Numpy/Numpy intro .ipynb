# %%
import numpy as np

# %%
# %%time

list1=[i for i in range(100000)] # we are seeing how much time it should take how much numpy take we compare
list2=[i for i in range(100000)]
# Out:
# CPU times: total: 46.9 ms
# Wall time: 45.6 ms

# %%
# %%time
a=np.arange(5) # very faster than python  numpy is also 19 times fater
a1=np.arange(5)
# Out:
# CPU times: total: 0 ns
# Wall time: 1.24 ms

# %%
# %%time
print(a)
# Out:
# [    0     1     2 ... 99997 99998 99999]
# CPU times: total: 0 ns
# Wall time: 1.62 ms

# %%
# %%time
l=list1*list2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
# %%time
m=a*a1
# Out:
# CPU times: total: 0 ns
# Wall time: 159 μs

# %%
print(m)
# Out:
# [ 0  1  4  9 16]

# %%
np.shape(a)
# Out:
# (5,)

# %%
print(len(a))
# Out:
# 5

# %%
np.size(a)
# Out:
# 5

# %%
n=np.array([1,7,8,6,9],dtype=np.int32)

# %%
b=np.size(n)

# %%
v=np.shape(n)

# %%
print(b)
print(v)
# Out:
# 5
# (5,)

# %%
print(type(n))
# Out:
# <class 'numpy.ndarray'>

# %%
print(n.dtype)
# Out:
# int32

# %%
g=np.array(["a","b","c","v","cc"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 g=np.array(["a","b","c","v","cc"],dtype=_string)
#
# NameError: name '_string' is not defined

# %%
s=np.array([0.87,0.65,0.23,0.87,1.98],dtype=np.float32) # changing data type float 64 to 32

# %%
print(s)
# Out:
# [0.87 0.65 0.23 0.87 1.98]

# %%
print(s.dtype)
# Out:
# float32

# %%
# also access like list index
print(n[0])
print(n[2])
print(n[-1])
# Out:
# 77
# 8
# 9

# %%
# also access like list index
print(g[0])
print(g[2])
print(g[-1])
print(g)
# Out:
# a
# c
# cc
# ['a' 'b' 'c' 'v' 'cc']

# %%
# also access like list index
print(s[0])
print(s[2])
print(s[-1])
print(s)
# Out:
# 0.87
# 0.23
# 1.98
# [0.87 0.65 0.23 0.87 1.98]

# %%
# also slicing or change or overwrite element
n[0]=77
print(n)
# Out:
# [77  7  8  6  9]

# %%
s[0]=9
print(s)
# Out:
# [9.   0.65 0.23 0.87 1.98]

# %%
g[0]=99
g[2]=8
g[4]="gg"
print(g)
# Out:
# ['99' 'b' '8' 'v' 'gg']

# %%
# one dimensional array
onedarray=np.array([1,2,4,5,6])

# %%
onedarray.dtype
# Out:
# dtype('int64')

# %%
print(onedarray[4])
# Out:
# 6

# %%
print(np.size(onedarray))
print(np.shape(onedarray))
# Out:
# 5
# (5,)

# %%
onedarray[0]=99
print(onedarray)
# Out:
# [99  2  4  5  6]

# %%
# two dimensional array
tn=np.array([[1,4,56,6,8],
            [4,2,6,7,"4"]],dtype=np.int64)

# %%
print(tn)
# Out:
# [[ 1  4 56  6  8]
#  [ 4  2  6  7  4]]

# %%
print(type(tn))
# Out:
# <class 'numpy.ndarray'>

# %%
print(tn.dtype)
# Out:
# int64

# %%
print(np.size(tn))
# Out:
# 10

# %%
print(np.shape(tn))
# Out:
# (2, 5)

# %%
# Zero row and column 
print(tn[0][0])
print(tn[0,4])
print(tn[0,1])
print(tn[0,2])
print(tn[0,3])
# Out:
# 1
# 8
# 4
# 56
# 6

# %%
print(tn[1][4])
# Out:
# 4

# %%
print(tn[1,0])
# Out:
# 4

# %%
print(tn[1,3])
# Out:
# 7

# %%
print(tn[1,2])
# Out:
# 6

# %%
print(tn[1,-3])
# Out:
# 6

# %%
tn[0][0]=99

# %%
print(tn)
# Out:
# [[99  4 56  6  8]
#  [ 4  2  6  7  4]]

# %%
tn[0,3]=64

# %%
tn[1,0]="768"
print(tn)
# Out:
# [[ 99   4  56  64   8]
#  [768   2   6   7   4]]
