# %%
import numpy as np

# %%
array1=np.array([
    [2,4,6,6,8,7],
    [5,0,7,3,9,6],
    [7,0,7,5,3,2]
])

# %%
array2=np.array([
    [7,5,99,7,0],
    [6,2,1,5,2]
])

# %%
array3=np.array([
    [8,9,2,1,4,3]
])

# %%
array1.max()
# Out:
# np.int64(9)

# %%
array1.min()
# Out:
# np.int64(0)

# %%
array2.max()
# Out:
# np.int64(99)

# %%
array2.min()
# Out:
# np.int64(0)

# %%
array3.max()
# Out:
# np.int64(9)

# %%
array2.min()
# Out:
# np.int64(0)

# %% [markdown]
# **FILTERING**

# %%
max=5
print(array1>max) # it gives in the form of true false
array1[array1>max]# it give in the form of numbers
array1[array1>max]=max
# Out:
# [[False False  True  True  True  True]
#  [False False  True False  True  True]
#  [ True False  True False False False]]

# %%
array1
# Out:
# array([[2, 4, 5, 5, 5, 5],
#        [5, 0, 5, 3, 5, 5],
#        [5, 0, 5, 5, 3, 2]])

# %%
ab=np.array([4,8,99,2,1,0])

# %%
ab[ab>max]
# Out:
# array([ 8, 99])

# %%
ab[ab>max]=max

# %%
ab
# Out:
# array([4, 5, 5, 2, 1, 0])

# %% [markdown]
# **Stacking
# Joins a sequence of an arrays along new axis** it is method of joinig method arrray along horizontal axis or vertical axis

# %%
a=np.array([
    [1,2,3,2,4,5],
    [9,7,99,5,2,1]
])

# %%
b=np.array([[8,4,2,1,5],
           [9,7,5,8,9]])

# %%
bn
# Out:
# array([[ 1,  2,  3,  2,  4,  5,  8,  4,  2,  1,  5],
#        [ 9,  7, 99,  5,  2,  1,  9,  7,  5,  8,  9]])

# %%
nn=np.array([
    [[9,3,2,5],
     [9,4,2,5]],
    [[8,5,3,6],
     [9,8,0,6]]
])

# %%
a=np.array([1,2,3,4,5])
b=np.array([
    [1,2,4,5,5],
    [5,3,1,4,3]
])

# %%
abb=np.vstack((a,b))

# %%
abb
# Out:
# array([[1, 2, 3, 4, 5],
#        [1, 2, 4, 5, 5],
#        [5, 3, 1, 4, 3]])

# %%
aaa=np.array([1,2,4])
bbb=np.array([[2,5,3,45,2,5]])

# %%
aabbb=np.hstack((a,b))

# %%
aaa=aaa.reshape(1,-1)

# %%
aabbb
# Out:
# array([[ 1,  2,  3,  2,  4,  5,  8,  4,  2,  1,  5],
#        [ 9,  7, 99,  5,  2,  1,  9,  7,  5,  8,  9]])
